# %%
import os
import glob
import datetime as dt
import numpy as np
import xarray as xr
import pandas as pd
from sublimpy import utils, extrautils
import matplotlib.pyplot as plt
import altair as alt
alt.data_transformers.enable('json')
import act

# %% [markdown]
# ## Horizontal wind - profiles

# %%
USERNAME = os.getenv("ARM_USERNAME")
TOKEN = os.getenv("ARM_TOKEN")
SAIL_DATA_STREAM = 'gucdlprofwind4newsM1.c1'
DATA_STREAM_FILEEXT = '.nc'
startdate = "2023-02-01"
enddate = "2023-06-01"
output_dir = os.path.join("/Users/elischwat/Development/data/sublimationofsnow/", SAIL_DATA_STREAM)

# %%
act.discovery.download_arm_data(USERNAME, TOKEN, SAIL_DATA_STREAM, startdate, enddate, output=output_dir)
# Out:
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230404.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230412.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230511.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230331.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230506.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230405.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230309.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230213.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230526.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230303.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230202.000039.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230301.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230414.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230214.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230222.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230421.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230224.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230312.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230311.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230513.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230418.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230323.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230504.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230419.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230220.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230510.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230509.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230307.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230406.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230420.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230430.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230423.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230207.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230210.000039.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230401.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230424.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230216.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230315.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230429.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230205.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230321.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230326.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230402.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230330.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230528.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230428.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230523.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230524.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230512.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230519.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230211.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230530.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230319.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230520.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230208.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230518.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230516.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230327.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230507.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230514.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230317.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230215.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230217.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230204.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230403.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230305.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230228.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230306.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230505.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230525.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230218.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230427.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230416.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230515.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230308.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230417.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230503.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230529.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230304.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230521.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230223.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230411.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230410.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230206.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230415.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230522.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230212.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230310.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230501.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230314.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230502.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230425.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230322.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230531.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230219.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230318.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230328.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230225.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230302.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230227.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230313.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230221.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230201.000039.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230226.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230527.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230325.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230203.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230517.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230324.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230426.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230408.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230422.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230329.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230413.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230209.000040.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230508.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230316.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230407.001421.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230320.001420.nc
# [DOWNLOADING] gucdlprofwind4newsM1.c1.20230409.001421.nc
#
# If you use these data to prepare a publication, please cite:
#
# Shippert, T., Newsom, R., Riihimaki, L., & Zhang, D. Doppler Lidar Horizontal
# Wind Profiles (DLPROFWIND4NEWS), 2023-02-01 to 2023-06-01, ARM Mobile Facility
# (GUC), Gunnison, CO; AMF2 (main site for SAIL) (M1). Atmospheric Radiation
# Measurement (ARM) User Facility. https://doi.org/10.5439/1178582
# ['/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230404.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230412.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230511.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230331.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230506.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230405.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230309.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230213.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230526.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230303.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230202.000039.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230301.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230414.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230214.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230222.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230421.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230224.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230312.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230311.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230513.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230418.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230323.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230504.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230419.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230220.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230510.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230509.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230307.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230406.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230420.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230430.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230423.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230207.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230210.000039.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230401.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230424.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230216.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230315.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230429.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230205.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230321.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230326.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230402.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230330.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230528.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230428.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230523.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230524.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230512.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230519.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230211.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230530.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230319.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230520.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230208.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230518.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230516.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230327.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230507.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230514.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230317.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230215.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230217.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230204.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230403.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230305.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230228.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230306.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230505.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230525.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230218.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230427.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230416.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230515.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230308.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230417.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230503.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230529.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230304.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230521.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230223.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230411.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230410.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230206.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230415.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230522.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230212.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230310.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230501.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230314.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230502.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230425.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230322.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230531.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230219.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230318.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230328.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230225.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230302.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230227.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230313.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230221.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230201.000039.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230226.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230527.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230325.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230203.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230517.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230324.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230426.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230408.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230422.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230329.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230413.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230209.000040.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230508.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230316.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230407.001421.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230320.001420.nc',
#  '/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/gucdlprofwind4newsM1.c1.20230409.001421.nc']

# %%
dl_w_prof_files = glob.glob("/Users/elischwat/Development/data/sublimationofsnow/gucdlprofwind4newsM1.c1/*.nc")

# %%
prof_ds = act.io.read_arm_netcdf(dl_w_prof_files)
prof_ds.time.min(), prof_ds.time.max()
# Out:
# (<xarray.DataArray 'time' ()> Size: 8B
#  array('2023-02-01T00:00:39.881244000', dtype='datetime64[ns]'),
#  <xarray.DataArray 'time' ()> Size: 8B
#  array('2023-06-15T23:59:20.789108000', dtype='datetime64[ns]'))

# %%
prof_df = prof_ds.to_dataframe()
prof_df = utils.modify_df_timezone(prof_df.reset_index(), 'UTC', 'US/Mountain').set_index('time')

# %%
hourly_mean_prof_df = prof_df.query("height > 950").query("height < 1100")[['wind_speed', 'wind_direction']].reset_index().set_index('time').groupby(pd.Grouper(freq='60min')).mean()

# %%
synoptic_winds_30min = hourly_mean_prof_df.resample('30min').mean().ffill()
along_valley_wind_times = synoptic_winds_30min[
    (synoptic_winds_30min.wind_direction > 299)
    & (synoptic_winds_30min.wind_direction < 345 )
].index.values
cross_valley_wind_times = synoptic_winds_30min[
    (synoptic_winds_30min.wind_direction > 202)
    & (synoptic_winds_30min.wind_direction < 248 )
].index.values
len(cross_valley_wind_times), len(along_valley_wind_times)
# Out:
# (1648, 1040)

# %% [markdown]
# # Surface Measurements

# %%
sos_tidy_fn = f"../paper1/process_slow_data/tidy_df_20221101_20230619_planar_fit_multiplane_STRAIGHTUP_q7_flags9000_pf10.parquet"
tidy_df = pd.read_parquet(sos_tidy_fn)
# Convert data timezone to local and clean up data on the ends
# convert time column to datetime
tidy_df['time'] = pd.to_datetime(tidy_df['time'])
tidy_df = utils.modify_df_timezone(tidy_df, 'UTC', 'US/Mountain')
tidy_df = tidy_df[tidy_df.time > '20221107']

# %%
src = tidy_df[tidy_df.variable.isin(['tke_3m_c', 'spd_3m_c', 'w_h2o__3m_c', 'w_tc__3m_c'])].pivot(index='time', columns='variable', values='value')
src = pd.concat([
        src[src.index.isin(cross_valley_wind_times)].assign(synoptic_wind = 'cross valley'),
        src[src.index.isin(along_valley_wind_times)].assign(synoptic_wind = 'along valley')
    ])
src['sqrt(tke)'] = src['tke_3m_c']**0.5
turbulence_regime_scatter_chart = alt.Chart(
    src
).mark_circle(size=5, color='orange').encode(
    alt.X('spd_3m_c').scale(domain=[0, 10], clamp=True),
    alt.Y('sqrt(tke)'),
    alt.Color('synoptic_wind:N')
).properties(width=200, height = 200)
turbulence_regime_scatter_chart
# Out:
# alt.Chart(...)

# %%
src['spd bin'] = pd.cut(
    src['spd_3m_c'], 
    np.arange(0,11), 
    # labels = [f"{lo}-{hi}" for lo, hi in zip(np.arange(0,11), np.arange(1,11))]
    labels = [(lo + hi)/2 for lo, hi in zip(np.arange(0,11), np.arange(1,11))]
)

# %%
turbulence_regime_box_chart = alt.Chart(
    src
).mark_boxplot(outliers=False, opacity=0.5, box={'stroke': 'black'}).encode(
    alt.X('spd bin:Q').title('3m wind speed (m/s)'),
    alt.Y('sqrt(tke):Q'),
    alt.Color('synoptic_wind:N'),
).properties(width=200, height = 200)

# %%
(
    windspeed_casestudy_chart 
    | (
        regime_casestudy_chart 
        | (turbulence_regime_scatter_chart + turbulence_regime_box_chart)
    ).resolve_scale(y='shared', x='shared', color='independent')
).resolve_scale(color='independent')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 (
# ----> 2     windspeed_casestudy_chart
#       3     | (
#       4         regime_casestudy_chart
#       5         | (turbulence_regime_scatter_chart + turbulence_regime_box_chart)
#       6     ).resolve_scale(y='shared', x='shared', color='independent')
#       7 ).resolve_scale(color='independent')
#
# NameError: name 'windspeed_casestudy_chart' is not defined

# %%
(alt.Chart(
    src
).mark_boxplot(outliers=False, opacity=0.5, box={'stroke': 'black'}).encode(
    alt.X('spd bin:Q').title('3m wind speed (m/s)'),
    alt.Y('w_h2o__3m_c:Q').title('TKE at 3m (m²/s²)'),
    alt.Color('synoptic_wind:N'),
).properties(width=200, height = 200) | alt.Chart(
    src
).mark_boxplot(outliers=False, opacity=0.5, box={'stroke': 'black'}).encode(
    alt.X('spd bin:Q').title('3m wind speed (m/s)'),
    alt.Y('w_h2o__20m_c:Q').title('TKE at 3m (m²/s²)'),
    alt.Color('synoptic_wind:N'),
).properties(width=200, height = 200)).resolve_scale(x='shared', y='shared')

# %%
(alt.Chart(
    src
).mark_boxplot(outliers=False, opacity=0.5, box={'stroke': 'black'}).encode(
    alt.X('spd bin:Q').title('3m wind speed (m/s)'),
    alt.Y('w_tc__3m_c:Q').title('TKE at 3m (m²/s²)'),
    alt.Color('synoptic_wind:N'),
).properties(width=200, height = 200) | alt.Chart(
    src
).mark_boxplot(outliers=False, opacity=0.5, box={'stroke': 'black'}).encode(
    alt.X('spd bin:Q').title('3m wind speed (m/s)'),
    alt.Y('w_tc__20m_c:Q').title('TKE at 3m (m²/s²)'),
    alt.Color('synoptic_wind:N'),
).properties(width=200, height = 200)).resolve_scale(x='shared', y='shared')

# %%
turbulence_regime_box_chart

# %%
src['sqrt(tke)'] = src['tke_3m_c']**(0.5)
turbulence_regime_box_chart = alt.Chart(
    src
).mark_boxplot(opacity=0.5, box={'stroke': 'black'}, outliers=False).encode(
    alt.X('spd bin:Q').title('3m wind speed (m/s)'),
    alt.Y('sqrt(tke):Q').title('TKE at 3m (m²/s²)'),
    alt.Color('synoptic_wind:N'),
).properties(width=200, height = 200)

turbulence_regime_chart = (turbulence_regime_scatter_chart + turbulence_regime_box_chart).resolve_scale(
    x='shared'
)
turbulence_regime_chart

# %%
synoptic_winds_pdf_chart =alt.Chart(
    pd.concat([
        synoptic_winds_30min[synoptic_winds_30min.index.isin(cross_valley_wind_times)].assign(synoptic_wind = 'cross valley'),
        synoptic_winds_30min[synoptic_winds_30min.index.isin(along_valley_wind_times)].assign(synoptic_wind = 'along valley')
    ])
).transform_density(
    'wind_speed',
    as_ = ['wind speed', 'density'],
    groupby=['synoptic_wind']
).mark_line().encode(
    alt.X('wind speed:Q').title('1000m wind speed (m/s)'),
    alt.Y('density:Q').title('PDF (kernel density estimate)'),
    alt.Color('synoptic_wind:N').title(['Synoptic wind', 'direction'])
).properties(width = 200, height = 200)
synoptic_winds_pdf_chart

# %%
turbulence_regime_chart | synoptic_winds_pdf_chart

# %%
src = pd.concat([
    tidy_df.query("measurement == 'temperature'"),
    tidy_df.query("variable == 'Tsurf_c'"),
])

src = src[src.time <= '20230411 1600'][src.time >= '20230411 0900']
alt.Chart(src).mark_circle().encode(
    alt.X('value:Q').title('temp. (˚C)').axis(values=[0,2,4,6,8,10]),
    alt.Y('height:Q').title('height (m)'),
    alt.Facet('time:T', columns=5).header(format='April %d %H:%M')
).properties(width=100, height=100).display(renderer='svg')

# %%
src = pd.concat([
    tidy_df.query("measurement == 'temperature'"),
    tidy_df.query("variable == 'Tsurf_c'"),
])

src = src[src.time <= '20230211 1600'][src.time >= '20230211 0900']
alt.Chart(src).mark_circle().encode(
    alt.X('value:Q').title('temp. (˚C)'),
    alt.Y('height:Q').title('height (m)'),
    alt.Facet('time:T', columns=5).header(format='February %d %H:%M')
).properties(width=100, height=100).display(renderer='svg')

# %% [markdown]
# # Local Scaling - does MOST work ?

# %% [markdown]
# Calculate dimensionless wind gradient (stability correction) and the stability function (z/L)

# %%
# src = tidy_df [tidy_df.time > '20230415'][tidy_df.time < '20230418']
HEIGHT = 3
src = tidy_df.copy()
src = src[src.variable.isin([
    'u*_3m_c', 'spd_3m_c', 'L_3m_c', 'Tvirtual_3m_c', 'w_tc__3m_c', 'wind_gradient_3m_c', 'temp_gradient_3m_c'
])]
src = src.pivot_table(values='value', columns='variable', index='time')
src['L_3m_c'] = - (src['u*_3m_c']**3)*(src['Tvirtual_3m_c']+273.5) / (0.4 * 9.81 * src['w_tc__3m_c'])
src['z_over_l'] = HEIGHT / src['L_3m_c']
src['stability_correction'] = 0.4*HEIGHT*src['wind_gradient_3m_c']/src['u*_3m_c']

src_along_valley_times = src[src.index.isin(along_valley_wind_times)]
src_cross_valley_times = src[src.index.isin(cross_valley_wind_times)]

# %% [markdown]
# Create a fit line for a couple different stability corrections

# %%
def holtslag_and_debruin(zeta):
    return (
        1 + 0.7*zeta + 0.75*zeta*(6 - 0.35*zeta)*np.exp(-0.35*zeta)
    )
def lettau(zeta):
    return (1 + 4.5*zeta)**0.75
fits_domain_stable = pd.Series(np.linspace(0,2))
fits_domain_unstable = pd.Series(np.linspace(-2,0))
fits_df = pd.concat([
    pd.DataFrame({
        'z_over_l': fits_domain_stable,
        'stability_correction': fits_domain_stable.apply(lettau),
    }),
    pd.DataFrame({
        'z_over_l': fits_domain_unstable,
        'stability_correction': (1 - 15 * fits_domain_unstable)**(-0.25)
    })
])

# %%
alt.Chart(
    src
).mark_circle(size=2).encode(
    alt.X('z_over_l').scale(domain=[-2, 2], clamp=True),
    alt.Y('stability_correction').scale(domain=[0, 6], clamp=True)
).properties(title='All data') +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
).properties(width=250, height = 250)
# Out:
# alt.LayerChart(...)

# %%
y_max = 3.5
x_min = -1.0
x_max = 1.0
scatter_chart_base = alt.Chart(
).mark_circle(size=10).encode(
    alt.X('z_over_l').scale(domain=[x_min, x_max], clamp=True),
    alt.Y('stability_correction').scale(domain=[0, y_max], clamp=True)
).properties(title='All data') +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q').scale(domain=[x_min, x_max], clamp=True),
    alt.Y('stability_correction:Q').scale(domain=[0, y_max], clamp=True)
).properties(width=250, height = 250)

alt.layer(scatter_chart_base, 
    data=src_along_valley_times.query(f"z_over_l < {x_max}").query(f"z_over_l > {x_min}").query("stability_correction > 0").query(f"stability_correction < {y_max}")
).properties(title='Along valley winds') | alt.layer(scatter_chart_base, 
    data=src_cross_valley_times.query(f"z_over_l < {x_max}").query(f"z_over_l > {x_min}").query("stability_correction > 0").query(f"stability_correction < {y_max}")
).properties(title='Cross valley winds')
# Out:
# alt.HConcatChart(...)

# %%
import altair as alt

# Define the base chart for 2D histograms
histogram_base = alt.Chart().mark_rect().encode(
    alt.X('z_over_l:Q', bin=alt.Bin(step=0.1), scale=alt.Scale(domain=[-1, 1], clamp=True)),
    alt.Y('stability_correction:Q', bin=alt.Bin(step=0.1), scale=alt.Scale(domain=[0, 3], clamp=True)),
    alt.Color('count():O')
).properties(width=250, height=250)

# Create the line chart for fits_df
line_chart = alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)

# Combine the histograms and line chart
chart_along_valley = alt.layer(histogram_base, line_chart, data=src_along_valley_times).properties(title='Along valley winds')
chart_cross_valley = alt.layer(histogram_base, line_chart, data=src_cross_valley_times).properties(title='Cross valley winds')

# Display the charts side by side
chart_along_valley | chart_cross_valley
# Out:
# alt.HConcatChart(...)

# %%
all_data_chart = (alt.Chart(
    src.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10")
).mark_boxplot(outliers=False).encode(
    alt.X('z_over_l:Q').bin(step=0.2),
    alt.Y('stability_correction:Q')
) +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)).properties(title='All Data', width=250, height = 250)

along_valley_chart = (alt.Chart(
    src_along_valley_times.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10")
).mark_boxplot(outliers=False).encode(
    alt.X('z_over_l:Q').bin(step=0.2),
    alt.Y('stability_correction:Q')
) +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)).properties(title='Along-valley synoptic winds', width=250, height = 250)
cross_valley_chart = (alt.Chart(
    src_cross_valley_times.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10")
).mark_boxplot(outliers=False).encode(
    alt.X('z_over_l:Q').bin(step=0.2),
    alt.Y('stability_correction:Q')
) +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)).properties(title='Cross-valley synoptic winds', width=250, height = 250)
all_data_chart | along_valley_chart | cross_valley_chart
# Out:
# alt.HConcatChart(...)

# %%
all_data_chart = (alt.Chart(
    src.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10")
).mark_circle().encode(
    alt.X('z_over_l:Q').bin(step=0.2),
    alt.Y('median(stability_correction):Q')
) +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)).properties(title='All Data', width=250, height = 250)

along_valley_chart = (alt.Chart(
    src_along_valley_times.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10")
).mark_point().encode(
    alt.X('z_over_l:Q').bin(step=0.2),
    alt.Y('median(stability_correction):Q')
) +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)).properties(title='Along-valley synoptic winds', width=250, height = 250)
cross_valley_chart = (alt.Chart(
    src_cross_valley_times.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10")
).mark_point(shape='square').encode(
    alt.X('z_over_l:Q').bin(step=0.2),
    alt.Y('median(stability_correction):Q')
) +\
    alt.Chart(fits_df).mark_line(color='red').encode(
    alt.X('z_over_l:Q'),
    alt.Y('stability_correction:Q')
)).properties(title='Cross-valley synoptic winds', width=250, height = 250)
all_data_chart | along_valley_chart | cross_valley_chart
# Out:
# alt.HConcatChart(...)

# %%
combo_df = pd.concat([
    # src.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10").assign(category = 'all data'),
    src_along_valley_times.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10").assign(category = 'along valley'),
    src_cross_valley_times.query("z_over_l < 2").query("z_over_l > -2").query("stability_correction < 10").assign(category = 'cross valley'),
])

(
    # case study plot
    ####################################
    alt.Chart(
        pd.concat([
            src.loc['20230415'],
            src.loc['20230418']
        ]).reset_index().query("z_over_l < 2")
    ).mark_point(opacity=.5).encode(
        alt.X('z_over_l').scale(domain=[-2, 2], clamp=True),
        alt.Y('stability_correction').scale(domain=[0, 6], clamp=True),
        alt.Color('date(time):N')
    ) +\
        alt.Chart(fits_df).mark_line(color='red').encode(
        alt.X('z_over_l:Q'),
        alt.Y('stability_correction:Q')
    ).properties(title='Two days in April', width=150, height = 250)
    
    # summary study plot
    ####################################
    |
    (alt.Chart(
        combo_df
    ).mark_point().encode(
        alt.X('z_over_l:Q').bin(step=0.2).axis(values=[-2,-1,0,1,2], format='.0f', tickCount=5),
        alt.Y('median(stability_correction):Q'),
        alt.Color('category:N'),
    ) + alt.Chart(fits_df).mark_line(color='red').encode(
        alt.X('z_over_l:Q'),
        alt.Y('stability_correction:Q')
    )).properties(title='All Data', width=150, height = 250) 

).resolve_scale(color='independent').display(renderer='svg')
