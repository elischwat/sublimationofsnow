# %%
import numpy as np
import argparse
import pandas as pd
import glob
import datetime
import matplotlib.pyplot as plt
import act
import os
import sys
from tempfile import TemporaryDirectory
from matplotlib import patheffects as pe
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
USERNAME = os.getenv("ARM_USERNAME")
TOKEN = os.getenv("ARM_TOKEN")
SAIL_DATA_STREAM = 'gucdlrhiM1.b1'
SNR_THRESHOLD = 0.008
DATE_FORMAT = "%Y-%m-%d"
MAX_RANGE = 2000
date = '2023-02-27'
startdate = date
# also get data from the next day - UTC conversion
enddate = (
    datetime.datetime.strptime(date, DATE_FORMAT) + datetime.timedelta(hours=2)
).strftime(DATE_FORMAT)

# %% [markdown]
# # Download data

# %%
with TemporaryDirectory() as temp_dir:
    act.discovery.download_arm_data(USERNAME, TOKEN, SAIL_DATA_STREAM, startdate, enddate, output=temp_dir)
    print("Data download complete")
    dl_rhi_files = glob.glob(''.join([temp_dir, '/', SAIL_DATA_STREAM,'*cdf']))
    print(len(dl_rhi_files))
    print("Opening files")
    dl_rhi = act.io.arm.read_arm_netcdf(dl_rhi_files)
    print("Converting to dataframe")
    src_rhi = dl_rhi.to_dataframe().reset_index()
# Out:
# [DOWNLOADING] gucdlrhiM1.b1.20230227.001514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.023335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.024834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.030024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.031834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.033006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.034834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.041833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.043335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.050023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.050341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.051513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.053335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.090024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.090341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.091513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.091833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.100024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.100341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.104834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.110023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.110340.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.111513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.111833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.120023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.120341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.121514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.121833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.124513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.124833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.130024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.130341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.134514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.000024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.000341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.001833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.003009.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.010005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.010335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.011513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.011833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.020024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.020341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.021833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.023006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.024514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.030341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.031514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.033335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.034514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.040024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.040341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.041513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.043005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.044514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.044833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.051833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.053005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.054514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.054833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.003335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.004514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.004834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.013006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.013335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.014513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.014833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.021514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.060340.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.061513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.061834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.063335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.064833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.070023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.070340.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.071513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.073336.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.074834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.080024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.080341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.081514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.084834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.093006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.093335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.094514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.094833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.101514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.101833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.123006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.123335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.131514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.131834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.133005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.133335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.134833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.141834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.143335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.144513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.144833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.150024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.151834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.153335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.154514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.161833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.163005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.060023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.063005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.064513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.071834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.073005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.074514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.081834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.083006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.083335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.084513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.103005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.103335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.104514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.113006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.113335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.114833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.114514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.160024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.160342.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.161514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.170342.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.171514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.194514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.194833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.200024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.201513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.201834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.203335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.140024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.140340.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.141513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.143005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.150341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.151514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.153006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.154834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.174834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.180342.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.183005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.183335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.190024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.190341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.193005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.193335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.200340.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.203005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.204514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.204834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.211514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.213005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.213335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.223005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.224833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.163335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.164514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.164834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.170025.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.171834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.173005.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.173335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.174514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.180024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.181514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.181833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.184513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.184834.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.191514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.191833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.210023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.210341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.211833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.214514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.214833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.220023.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.220341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.221514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.221833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.223335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.224514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.230024.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.230341.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.231514.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.233006.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.233335.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.231833.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.234513.cdf
# [DOWNLOADING] gucdlrhiM1.b1.20230227.234833.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Newsom, R., Shi, Y., & Krishnamurthy, R. Doppler Lidar (DLRHI). Atmospheric
# Radiation Measurement (ARM) User Facility. https://doi.org/10.5439/1046188
#
# Data download complete
# 192
# Opening files
# Converting to dataframe

# %% [markdown]
# # Preprocess data

# %%
# Convert time zone
src_rhi['time'] = src_rhi['time'].dt.tz_localize('UTC').dt.tz_convert('US/Mountain')
src_rhi['time'] = pd.to_datetime(src_rhi['time'].dt.tz_localize(None))
# Shrink dataset by removing extra data
src_rhi = src_rhi.query(f"range < {MAX_RANGE}")
# Shrink dataset by isolating data to target day in local time
src_rhi = src_rhi[src_rhi['time'].dt.day == datetime.datetime.strptime(startdate, DATE_FORMAT).day]
# Filter with SNR
src_rhi['SNR'] = src_rhi['intensity'] - 1
src_rhi.loc[src_rhi.eval(f'SNR < {SNR_THRESHOLD}'), 'radial_velocity'] = np.nan
# Remove extraneous scan data
src_rhi = src_rhi.query("elevation != -0.01")
# Add useful columns
src_rhi['date'] = src_rhi['time'].dt.date
src_rhi['hour'] = src_rhi['time'].dt.hour
src_rhi['minute'] = src_rhi['time'].dt.minute
src_rhi['second'] = src_rhi['time'].dt.second
src_rhi['time_beginning_of_hour'] = src_rhi['time'].apply(lambda dt: dt.replace(minute=0, second=0, microsecond=0))
# RHI: convert polar coordinates to rectangular coords with the radar at (0,0)
src_rhi['x'] = src_rhi['range']*np.cos(np.deg2rad(src_rhi['elevation']))
src_rhi['z'] = src_rhi['range']*np.sin(np.deg2rad(src_rhi['elevation']))

# %% [markdown]
# # Separate cross vally and along valley scans

# %%
scan_azimuth_valley_wise = 149
scan_azimuth_valley_cross = 270

# %%
# Split dataset into valley-wise and cross-valley RHI scans
valley_rhi_df = src_rhi[np.abs(src_rhi['azimuth'] - scan_azimuth_valley_wise) < 1]
xvalley_rhi_df = src_rhi[np.abs(src_rhi['azimuth'] - scan_azimuth_valley_cross) < 1]

# Label the 4 cross-valley scans that happen each hour
# We do this by defining the "hourly seconds" (second for a data point where 0 seconds is 
# at the beginning of the hour)
# and saying that all data from after 913 (after 15:13 mm:ss) and before 1113 (before 18:13 
# mm:ss) is the first scan, and so on - this may be imperfect
xvalley_rhi_df['hourly_seconds'] = xvalley_rhi_df.apply(lambda row: row['minute']*60 + row['second'], axis=1)
xvalley_rhi_df['hourly_scan_n'] = pd.cut(
    xvalley_rhi_df['hourly_seconds'],
    [913, 1113, 2713, 2913, 3599],
    labels=['15.00','18.00','45.00','48.00']
)

# Label the 4 valley-wise scans that happen each hour
# similarly to above
valley_rhi_df['hourly_seconds'] = valley_rhi_df.apply(lambda row: row['minute']*60 + row['second'], axis=1)
valley_rhi_df['hourly_scan_n'] = pd.cut(
    valley_rhi_df['hourly_seconds'],
    [22, 214, 1804, 2014, 3599],
    labels=['00.00','03.00','30.00','33.00']
)
# Out:
# /var/folders/x_/2h52bcjx2px15bhmdpdd748h0000gn/T/ipykernel_76018/2031976061.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xvalley_rhi_df['hourly_seconds'] = xvalley_rhi_df.apply(lambda row: row['minute']*60 + row['second'], axis=1)
# /var/folders/x_/2h52bcjx2px15bhmdpdd748h0000gn/T/ipykernel_76018/2031976061.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xvalley_rhi_df['hourly_scan_n'] = pd.cut(
# /var/folders/x_/2h52bcjx2px15bhmdpdd748h0000gn/T/ipykernel_76018/2031976061.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valley_rhi_df['hourly_seconds'] = valley_rhi_df.apply(lambda row: row['minute']*60 + row['second'], axis=1)
# /var/folders/x_/2h52bcjx2px15bhmdpdd748h0000gn/T/ipykernel_76018/2031976061.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valley_rhi_df['hourly_scan_n'] = pd.cut(

# %% [markdown]
# # Extract profile at given upvalley/downvalley distances

# %%
import datetime as dt
import altair as alt
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
src = valley_rhi_df[np.abs(valley_rhi_df['x'] + 1000) < 100]
src['scan_time'] = src.apply(lambda row : row['time_beginning_of_hour']+ dt.timedelta(minutes = float(row['hourly_scan_n'])), axis=1)
src = src[['scan_time', 'radial_velocity', 'z', 'x']]
src['z_binned'] = pd.cut(src.z, bins=np.linspace(0,2000,41)).apply(lambda bin: (bin.left + bin.right)/2)
src = src.groupby(["scan_time", 'z_binned']).median().reset_index()
# Out:
# /var/folders/x_/2h52bcjx2px15bhmdpdd748h0000gn/T/ipykernel_76018/881119343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   src['scan_time'] = src.apply(lambda row : row['time_beginning_of_hour']+ dt.timedelta(minutes = float(row['hourly_scan_n'])), axis=1)
# /var/folders/x_/2h52bcjx2px15bhmdpdd748h0000gn/T/ipykernel_76018/881119343.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   src = src.groupby(["scan_time", 'z_binned']).median().reset_index()

# %%
# rule = alt.Chart().transform_calculate(rule="0").mark_rule().encode(x='rule:Q')
alt.Chart(
    src[
        (src.scan_time.dt.hour >= 0)
        &
        (src.scan_time.dt.hour < 13)
    ].query("z <= 500").query("z >= 30")
).mark_line().encode(
    alt.X("radial_velocity:Q").sort('-y').scale(domain=[-12,12], clamp=True),
    alt.Y("z_binned:Q"),
    alt.Facet("scan_time:T", columns=10).header(format='%H:%M')
).properties(width = 100, height = 100)
# Out:
# alt.Chart(...)
