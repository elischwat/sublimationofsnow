# %%
import pandas as pd
import glob
import altair as alt
from sublimpy import utils
import datetime as dt
import numpy as np

# %%
files = glob.glob("turb_datasets/tidy_df**.parquet")
df = pd.DataFrame()
for file in files:
    local = pd.read_parquet(file).query("measurement == 'w_h2o_'")
    df = pd.concat([df, local.assign(filename = file)])
df = df[df.variable.isin([
    'w_h2o__2m_c', 'w_h2o__3m_c', 'w_h2o__5m_c', 'w_h2o__10m_c', 'w_h2o__15m_c', 'w_h2o__20m_c', 
    'w_h2o__3m_uw', 'w_h2o__10m_uw', 
    'w_h2o__3m_ue', 'w_h2o__10m_ue', 
    'w_h2o__3m_d', 'w_h2o__10m_d', 
])]
df = utils.modify_df_timezone(df, 'UTC', 'US/Mountain')
df = df[(df['time'] > '20221130') & (df['time'] < '20230508')]

# %%
df['filename'] = df['filename'].str.replace('turb_datasets/tidy_df_20221101_20230619_planar_fit_multiplane_STRAIGHTUP_', '')
df['processing'] = df['filename'].str.replace('.parquet', '')

# %%
df.head()

# %%
df.value = df.value.where(df.value < 0.5, other=0)

# %% [markdown]
# # Calculate and plot seasonal totals

# %%
totals_df = pd.DataFrame(df.groupby(['variable', 'processing'])['value'].sum()*30*60/1000).reset_index()

# %%
totals_df['despiking'] = totals_df['processing'].apply(lambda s: s.split('_')[0])
totals_df['instrument_flagging'] = totals_df['processing'].apply(lambda s: s.split('_')[1])
totals_df['snowfall_filtering'] = totals_df['processing'].apply(lambda s: s.split('_')[2])
totals_df['height'] = totals_df['variable'].str.split('_').str[3].str[:-1].astype(int)
totals_df['tower'] = totals_df['variable'].str.split('_').str[-1]
totals_df

# %%
alt.Chart(totals_df).mark_point(size=100).encode(
    alt.X('value:Q').scale(zero=False, domain=[20,40]),
    alt.Y('height:Q'),
    alt.Shape('tower:N'),
    alt.Column('instrument_flagging').sort(['flags36000', 'flags9000', 'flags3600']),
    alt.Row('despiking'),
    alt.Color('snowfall_filtering')
).properties(width=150, height = 150)
# Out:
# alt.Chart(...)

# %%
processing_options = df.processing.unique()
local = pd.DataFrame()
for process in processing_options:
    local = pd.concat([
        local,
        df.query("variable == 'w_h2o__20m_c'").query(f"processing == '{process}'").set_index('time').sort_index()[['value']].cumsum().assign(processing = process)
    ])
local['value'] = local['value']*1.8
local['despiking'] = local['processing'].apply(lambda s: s.split('_')[0])
local['instrument_flagging'] = local['processing'].apply(lambda s: s.split('_')[1])
local['snowfall_filtering'] = local['processing'].apply(lambda s: s.split('_')[2])

# %% [markdown]
# # Calculate and examine seasonal cumulative

# %%
alt.data_transformers.enable('json')

# %%
alt.Chart(local.reset_index().dropna()).mark_line().encode(
    alt.X('time:T'),
    alt.Y('value:Q'),
    alt.Color('processing:N'),
    alt.Row('snowfall_filtering:N'),
    tooltip = 'processing:N'
).properties(width=1000).resolve_scale(color='independent')

# %%
pd.options.display.max_rows = 500
display(df.groupby(['variable','processing']).value.max())

# %%
def restrict_time(src):
    return src[
        (
            src.time > '20230111'
        )&(
            src.time < '20230111 0600'
        )
    ]
alt.Chart(restrict_time(
    df.query("variable == 'w_h2o__20m_c'")
)).mark_line().encode(
    alt.X('time:T'),
    alt.Y('value:Q'),
    alt.Color('processing'),
    facet='processing'
)
# Out:
# alt.Chart(...)

# %%
def restrict_time(src):
    return src[
        (
            src.time > '20221221'
        )&(
            src.time < '20221223'
        )
    ]
alt.Chart(restrict_time(
    df.query("variable == 'w_h2o__20m_c'")
)).mark_line().encode(
    alt.X('time:T'),
    alt.Y('value:Q'),
    alt.Color('processing'),
    facet='processing'
)
# Out:
# alt.Chart(...)

# %%
restrict_time(
    df.query("variable == 'w_h2o__20m_c'")
).value.value_counts()

# %% [markdown]
# # Apply mean diurnal gap filling

# %%
df_gapfilled = pd.DataFrame()
for lhflux_variable in df.variable.unique():
    for process in df.processing.unique():
        subset = df.query(f"variable == '{lhflux_variable}'")
        subset = subset.query(f"processing == '{process}'")
        subset = subset.set_index('time')
        for i,row in subset.iterrows():
            if np.isnan(row['value']) or row['value'] == 0:
                start_window = i - dt.timedelta(days=3, hours=12)
                end_window = i + dt.timedelta(days=3, hours=12)
                src = subset.loc[start_window: end_window].reset_index()
                means = pd.DataFrame(
                    src.groupby([src.time.dt.hour, src.time.dt.minute])['value'].mean()
                )
                subset.loc[i, 'value'] = means.loc[i.hour, i.minute].value
        df_gapfilled = pd.concat([df_gapfilled, subset])

# %%
totals_gapfilled_df = pd.DataFrame(df_gapfilled.groupby(['variable', 'processing'])['value'].sum()*30*60/1000).reset_index()

# %%
totals_gapfilled_df['despiking'] = totals_gapfilled_df['processing'].apply(lambda s: s.split('_')[0])
totals_gapfilled_df['instrument_flagging'] = totals_gapfilled_df['processing'].apply(lambda s: s.split('_')[1])
totals_gapfilled_df['snowfall_filtering'] = totals_gapfilled_df['processing'].apply(lambda s: s.split('_')[2])
totals_gapfilled_df['height'] = totals_gapfilled_df['variable'].str.split('_').str[3].str[:-1].astype(int)
totals_gapfilled_df['tower'] = totals_gapfilled_df['variable'].str.split('_').str[-1]
totals_gapfilled_df
# Out:
#           variable                                    processing      value  \
# 0     w_h2o__10m_c  nodespiking_flags36000_snowfallfiltered0.5mm  39.902017
# 1     w_h2o__10m_c    nodespiking_flags36000_snowfallfiltered0mm  39.221165
# 2     w_h2o__10m_c     nodespiking_flags36000_snowfallfilteredno  39.120948
# 3     w_h2o__10m_c   nodespiking_flags3600_snowfallfiltered0.5mm  38.070777
# 4     w_h2o__10m_c     nodespiking_flags3600_snowfallfiltered0mm  37.454751
# 5     w_h2o__10m_c      nodespiking_flags3600_snowfallfilteredno  37.401353
# 6     w_h2o__10m_c   nodespiking_flags9000_snowfallfiltered0.5mm  38.856018
# 7     w_h2o__10m_c     nodespiking_flags9000_snowfallfiltered0mm  37.954073
# 8     w_h2o__10m_c      nodespiking_flags9000_snowfallfilteredno  37.900676
# 9     w_h2o__10m_c           q7_flags36000_snowfallfiltered0.5mm  38.011942
# 10    w_h2o__10m_c             q7_flags36000_snowfallfiltered0mm  37.286491
# 11    w_h2o__10m_c              q7_flags36000_snowfallfilteredno  38.011942
# 12    w_h2o__10m_c            q7_flags3600_snowfallfiltered0.5mm  36.349428
# 13    w_h2o__10m_c              q7_flags3600_snowfallfiltered0mm  35.653460
# 14    w_h2o__10m_c               q7_flags3600_snowfallfilteredno  36.349428
# 15    w_h2o__10m_c            q7_flags9000_snowfallfiltered0.5mm  37.151010
# 16    w_h2o__10m_c              q7_flags9000_snowfallfiltered0mm  36.174665
# 17    w_h2o__10m_c               q7_flags9000_snowfallfilteredno  37.151010
# 18    w_h2o__10m_d  nodespiking_flags36000_snowfallfiltered0.5mm  36.132144
# 19    w_h2o__10m_d    nodespiking_flags36000_snowfallfiltered0mm  35.520006
# 20    w_h2o__10m_d     nodespiking_flags36000_snowfallfilteredno  35.513769
# 21    w_h2o__10m_d   nodespiking_flags3600_snowfallfiltered0.5mm  36.804229
# 22    w_h2o__10m_d     nodespiking_flags3600_snowfallfiltered0mm  36.507979
# 23    w_h2o__10m_d      nodespiking_flags3600_snowfallfilteredno  36.495217
# 24    w_h2o__10m_d   nodespiking_flags9000_snowfallfiltered0.5mm  36.337717
# 25    w_h2o__10m_d     nodespiking_flags9000_snowfallfiltered0mm  35.882611
# 26    w_h2o__10m_d      nodespiking_flags9000_snowfallfilteredno  35.869850
# 27    w_h2o__10m_d           q7_flags36000_snowfallfiltered0.5mm  36.074700
# 28    w_h2o__10m_d             q7_flags36000_snowfallfiltered0mm  35.500590
# 29    w_h2o__10m_d              q7_flags36000_snowfallfilteredno  36.074700
# 30    w_h2o__10m_d            q7_flags3600_snowfallfiltered0.5mm  35.560187
# 31    w_h2o__10m_d              q7_flags3600_snowfallfiltered0mm  35.197480
# 32    w_h2o__10m_d               q7_flags3600_snowfallfilteredno  35.560187
# 33    w_h2o__10m_d            q7_flags9000_snowfallfiltered0.5mm  35.069783
# 34    w_h2o__10m_d              q7_flags9000_snowfallfiltered0mm  34.551198
# 35    w_h2o__10m_d               q7_flags9000_snowfallfilteredno  35.069783
# 36   w_h2o__10m_ue  nodespiking_flags36000_snowfallfiltered0.5mm  32.872558
# 37   w_h2o__10m_ue    nodespiking_flags36000_snowfallfiltered0mm  31.921903
# 38   w_h2o__10m_ue     nodespiking_flags36000_snowfallfilteredno  32.012758
# 39   w_h2o__10m_ue   nodespiking_flags3600_snowfallfiltered0.5mm  30.907577
# 40   w_h2o__10m_ue     nodespiking_flags3600_snowfallfiltered0mm  30.187338
# 41   w_h2o__10m_ue      nodespiking_flags3600_snowfallfilteredno  30.301520
# 42   w_h2o__10m_ue   nodespiking_flags9000_snowfallfiltered0.5mm  31.581705
# 43   w_h2o__10m_ue     nodespiking_flags9000_snowfallfiltered0mm  30.733809
# 44   w_h2o__10m_ue      nodespiking_flags9000_snowfallfilteredno  30.840914
# 45   w_h2o__10m_ue           q7_flags36000_snowfallfiltered0.5mm  32.873180
# 46   w_h2o__10m_ue             q7_flags36000_snowfallfiltered0mm  31.701033
# 47   w_h2o__10m_ue              q7_flags36000_snowfallfilteredno  32.873180
# 48   w_h2o__10m_ue            q7_flags3600_snowfallfiltered0.5mm  30.925229
# 49   w_h2o__10m_ue              q7_flags3600_snowfallfiltered0mm  30.004418
# 50   w_h2o__10m_ue               q7_flags3600_snowfallfilteredno  30.925229
# 51   w_h2o__10m_ue            q7_flags9000_snowfallfiltered0.5mm  31.635204
# 52   w_h2o__10m_ue              q7_flags9000_snowfallfiltered0mm  30.582218
# 53   w_h2o__10m_ue               q7_flags9000_snowfallfilteredno  31.635204
# 54   w_h2o__10m_uw  nodespiking_flags36000_snowfallfiltered0.5mm  37.949024
# 55   w_h2o__10m_uw    nodespiking_flags36000_snowfallfiltered0mm  37.315268
# 56   w_h2o__10m_uw     nodespiking_flags36000_snowfallfilteredno  37.297883
# 57   w_h2o__10m_uw   nodespiking_flags3600_snowfallfiltered0.5mm  37.338313
# 58   w_h2o__10m_uw     nodespiking_flags3600_snowfallfiltered0mm  37.079344
# 59   w_h2o__10m_uw      nodespiking_flags3600_snowfallfilteredno  37.066979
# 60   w_h2o__10m_uw   nodespiking_flags9000_snowfallfiltered0.5mm  37.504127
# 61   w_h2o__10m_uw     nodespiking_flags9000_snowfallfiltered0mm  37.163744
# 62   w_h2o__10m_uw      nodespiking_flags9000_snowfallfilteredno  37.164764
# 63   w_h2o__10m_uw           q7_flags36000_snowfallfiltered0.5mm  37.266962
# 64   w_h2o__10m_uw             q7_flags36000_snowfallfiltered0mm  36.385584
# 65   w_h2o__10m_uw              q7_flags36000_snowfallfilteredno  37.266962
# 66   w_h2o__10m_uw            q7_flags3600_snowfallfiltered0.5mm  35.874874
# 67   w_h2o__10m_uw              q7_flags3600_snowfallfiltered0mm  35.424998
# 68   w_h2o__10m_uw               q7_flags3600_snowfallfilteredno  35.874874
# 69   w_h2o__10m_uw            q7_flags9000_snowfallfiltered0.5mm  36.095647
# 70   w_h2o__10m_uw              q7_flags9000_snowfallfiltered0mm  35.491850
# 71   w_h2o__10m_uw               q7_flags9000_snowfallfilteredno  36.095647
# 72    w_h2o__15m_c  nodespiking_flags36000_snowfallfiltered0.5mm  28.683430
# 73    w_h2o__15m_c    nodespiking_flags36000_snowfallfiltered0mm  28.000183
# 74    w_h2o__15m_c     nodespiking_flags36000_snowfallfilteredno  28.036045
# 75    w_h2o__15m_c   nodespiking_flags3600_snowfallfiltered0.5mm  28.183532
# 76    w_h2o__15m_c     nodespiking_flags3600_snowfallfiltered0mm  27.896375
# 77    w_h2o__15m_c      nodespiking_flags3600_snowfallfilteredno  27.947752
# 78    w_h2o__15m_c   nodespiking_flags9000_snowfallfiltered0.5mm  28.913624
# 79    w_h2o__15m_c     nodespiking_flags9000_snowfallfiltered0mm  28.186700
# 80    w_h2o__15m_c      nodespiking_flags9000_snowfallfilteredno  28.239012
# 81    w_h2o__15m_c           q7_flags36000_snowfallfiltered0.5mm  27.733353
# 82    w_h2o__15m_c             q7_flags36000_snowfallfiltered0mm  26.705462
# 83    w_h2o__15m_c              q7_flags36000_snowfallfilteredno  27.733353
# 84    w_h2o__15m_c            q7_flags3600_snowfallfiltered0.5mm  27.897448
# 85    w_h2o__15m_c              q7_flags3600_snowfallfiltered0mm  27.114830
# 86    w_h2o__15m_c               q7_flags3600_snowfallfilteredno  27.897448
# 87    w_h2o__15m_c            q7_flags9000_snowfallfiltered0.5mm  28.184424
# 88    w_h2o__15m_c              q7_flags9000_snowfallfiltered0mm  27.124599
# 89    w_h2o__15m_c               q7_flags9000_snowfallfilteredno  28.184424
# 90    w_h2o__20m_c  nodespiking_flags36000_snowfallfiltered0.5mm  29.302591
# 91    w_h2o__20m_c    nodespiking_flags36000_snowfallfiltered0mm  27.375368
# 92    w_h2o__20m_c     nodespiking_flags36000_snowfallfilteredno  27.359523
# 93    w_h2o__20m_c   nodespiking_flags3600_snowfallfiltered0.5mm  28.385476
# 94    w_h2o__20m_c     nodespiking_flags3600_snowfallfiltered0mm  27.010265
# 95    w_h2o__20m_c      nodespiking_flags3600_snowfallfilteredno  27.012878
# 96    w_h2o__20m_c   nodespiking_flags9000_snowfallfiltered0.5mm  28.251888
# 97    w_h2o__20m_c     nodespiking_flags9000_snowfallfiltered0mm  26.573028
# 98    w_h2o__20m_c      nodespiking_flags9000_snowfallfilteredno  26.575640
# 99    w_h2o__20m_c           q7_flags36000_snowfallfiltered0.5mm  28.099542
# 100   w_h2o__20m_c             q7_flags36000_snowfallfiltered0mm  27.014772
# 101   w_h2o__20m_c              q7_flags36000_snowfallfilteredno  28.099542
# 102   w_h2o__20m_c            q7_flags3600_snowfallfiltered0.5mm  27.285404
# 103   w_h2o__20m_c              q7_flags3600_snowfallfiltered0mm  26.353953
# 104   w_h2o__20m_c               q7_flags3600_snowfallfilteredno  27.285404
# 105   w_h2o__20m_c            q7_flags9000_snowfallfiltered0.5mm  27.346864
# 106   w_h2o__20m_c              q7_flags9000_snowfallfiltered0mm  26.100710
# 107   w_h2o__20m_c               q7_flags9000_snowfallfilteredno  27.346864
# 108    w_h2o__2m_c  nodespiking_flags36000_snowfallfiltered0.5mm  31.479210
# 109    w_h2o__2m_c    nodespiking_flags36000_snowfallfiltered0mm  31.453511
# 110    w_h2o__2m_c     nodespiking_flags36000_snowfallfilteredno  31.462887
# 111    w_h2o__2m_c   nodespiking_flags3600_snowfallfiltered0.5mm  30.349712
# 112    w_h2o__2m_c     nodespiking_flags3600_snowfallfiltered0mm  30.587602
# 113    w_h2o__2m_c      nodespiking_flags3600_snowfallfilteredno  30.581526
# 114    w_h2o__2m_c   nodespiking_flags9000_snowfallfiltered0.5mm  31.008962
# 115    w_h2o__2m_c     nodespiking_flags9000_snowfallfiltered0mm  31.075534
# 116    w_h2o__2m_c      nodespiking_flags9000_snowfallfilteredno  31.084740
# 117    w_h2o__2m_c           q7_flags36000_snowfallfiltered0.5mm  31.761973
# 118    w_h2o__2m_c             q7_flags36000_snowfallfiltered0mm  31.316538
# 119    w_h2o__2m_c              q7_flags36000_snowfallfilteredno  31.761973
# 120    w_h2o__2m_c            q7_flags3600_snowfallfiltered0.5mm  30.658184
# 121    w_h2o__2m_c              q7_flags3600_snowfallfiltered0mm  30.452965
# 122    w_h2o__2m_c               q7_flags3600_snowfallfilteredno  30.658184
# 123    w_h2o__2m_c            q7_flags9000_snowfallfiltered0.5mm  31.293977
# 124    w_h2o__2m_c              q7_flags9000_snowfallfiltered0mm  30.929875
# 125    w_h2o__2m_c               q7_flags9000_snowfallfilteredno  31.293977
# 126    w_h2o__3m_c  nodespiking_flags36000_snowfallfiltered0.5mm  36.311507
# 127    w_h2o__3m_c    nodespiking_flags36000_snowfallfiltered0mm  35.517402
# 128    w_h2o__3m_c     nodespiking_flags36000_snowfallfilteredno  35.518719
# 129    w_h2o__3m_c   nodespiking_flags3600_snowfallfiltered0.5mm  35.355892
# 130    w_h2o__3m_c     nodespiking_flags3600_snowfallfiltered0mm  34.934170
# 131    w_h2o__3m_c      nodespiking_flags3600_snowfallfilteredno  34.935382
# 132    w_h2o__3m_c   nodespiking_flags9000_snowfallfiltered0.5mm  35.837309
# 133    w_h2o__3m_c     nodespiking_flags9000_snowfallfiltered0mm  35.342948
# 134    w_h2o__3m_c      nodespiking_flags9000_snowfallfilteredno  35.344160
# 135    w_h2o__3m_c           q7_flags36000_snowfallfiltered0.5mm  35.097264
# 136    w_h2o__3m_c             q7_flags36000_snowfallfiltered0mm  34.326459
# 137    w_h2o__3m_c              q7_flags36000_snowfallfilteredno  35.097264
# 138    w_h2o__3m_c            q7_flags3600_snowfallfiltered0.5mm  34.105529
# 139    w_h2o__3m_c              q7_flags3600_snowfallfiltered0mm  33.721445
# 140    w_h2o__3m_c               q7_flags3600_snowfallfilteredno  34.105529
# 141    w_h2o__3m_c            q7_flags9000_snowfallfiltered0.5mm  34.558932
# 142    w_h2o__3m_c              q7_flags9000_snowfallfiltered0mm  34.106557
# 143    w_h2o__3m_c               q7_flags9000_snowfallfilteredno  34.558932
# 144    w_h2o__3m_d  nodespiking_flags36000_snowfallfiltered0.5mm  34.923505
# 145    w_h2o__3m_d    nodespiking_flags36000_snowfallfiltered0mm  34.491449
# 146    w_h2o__3m_d     nodespiking_flags36000_snowfallfilteredno  34.437211
# 147    w_h2o__3m_d   nodespiking_flags3600_snowfallfiltered0.5mm  34.514610
# 148    w_h2o__3m_d     nodespiking_flags3600_snowfallfiltered0mm  34.263686
# 149    w_h2o__3m_d      nodespiking_flags3600_snowfallfilteredno  34.225039
# 150    w_h2o__3m_d   nodespiking_flags9000_snowfallfiltered0.5mm  34.624367
# 151    w_h2o__3m_d     nodespiking_flags9000_snowfallfiltered0mm  34.299888
# 152    w_h2o__3m_d      nodespiking_flags9000_snowfallfilteredno  34.256306
# 153    w_h2o__3m_d           q7_flags36000_snowfallfiltered0.5mm  35.062215
# 154    w_h2o__3m_d             q7_flags36000_snowfallfiltered0mm  34.601072
# 155    w_h2o__3m_d              q7_flags36000_snowfallfilteredno  35.062215
# 156    w_h2o__3m_d            q7_flags3600_snowfallfiltered0.5mm  34.470076
# 157    w_h2o__3m_d              q7_flags3600_snowfallfiltered0mm  34.189795
# 158    w_h2o__3m_d               q7_flags3600_snowfallfilteredno  34.470076
# 159    w_h2o__3m_d            q7_flags9000_snowfallfiltered0.5mm  34.618269
# 160    w_h2o__3m_d              q7_flags9000_snowfallfiltered0mm  34.269868
# 161    w_h2o__3m_d               q7_flags9000_snowfallfilteredno  34.618269
# 162   w_h2o__3m_ue  nodespiking_flags36000_snowfallfiltered0.5mm  37.542996
# 163   w_h2o__3m_ue    nodespiking_flags36000_snowfallfiltered0mm  37.152096
# 164   w_h2o__3m_ue     nodespiking_flags36000_snowfallfilteredno  37.097984
# 165   w_h2o__3m_ue   nodespiking_flags3600_snowfallfiltered0.5mm  36.227343
# 166   w_h2o__3m_ue     nodespiking_flags3600_snowfallfiltered0mm  35.957722
# 167   w_h2o__3m_ue      nodespiking_flags3600_snowfallfilteredno  35.916779
# 168   w_h2o__3m_ue   nodespiking_flags9000_snowfallfiltered0.5mm  36.563137
# 169   w_h2o__3m_ue     nodespiking_flags9000_snowfallfiltered0mm  36.217308
# 170   w_h2o__3m_ue      nodespiking_flags9000_snowfallfilteredno  36.176365
# 171   w_h2o__3m_ue           q7_flags36000_snowfallfiltered0.5mm  36.350969
# 172   w_h2o__3m_ue             q7_flags36000_snowfallfiltered0mm  35.913361
# 173   w_h2o__3m_ue              q7_flags36000_snowfallfilteredno  36.350969
# 174   w_h2o__3m_ue            q7_flags3600_snowfallfiltered0.5mm  35.138135
# 175   w_h2o__3m_ue              q7_flags3600_snowfallfiltered0mm  34.817747
# 176   w_h2o__3m_ue               q7_flags3600_snowfallfilteredno  35.138135
# 177   w_h2o__3m_ue            q7_flags9000_snowfallfiltered0.5mm  35.459514
# 178   w_h2o__3m_ue              q7_flags9000_snowfallfiltered0mm  35.066400
# 179   w_h2o__3m_ue               q7_flags9000_snowfallfilteredno  35.459514
# 180   w_h2o__3m_uw  nodespiking_flags36000_snowfallfiltered0.5mm  36.258731
# 181   w_h2o__3m_uw    nodespiking_flags36000_snowfallfiltered0mm  35.986480
# 182   w_h2o__3m_uw     nodespiking_flags36000_snowfallfilteredno  35.872059
# 183   w_h2o__3m_uw   nodespiking_flags3600_snowfallfiltered0.5mm  35.343225
# 184   w_h2o__3m_uw     nodespiking_flags3600_snowfallfiltered0mm  35.271187
# 185   w_h2o__3m_uw      nodespiking_flags3600_snowfallfilteredno  35.151184
# 186   w_h2o__3m_uw   nodespiking_flags9000_snowfallfiltered0.5mm  35.740559
# 187   w_h2o__3m_uw     nodespiking_flags9000_snowfallfiltered0mm  35.537384
# 188   w_h2o__3m_uw      nodespiking_flags9000_snowfallfilteredno  35.417381
# 189   w_h2o__3m_uw           q7_flags36000_snowfallfiltered0.5mm  35.521246
# 190   w_h2o__3m_uw             q7_flags36000_snowfallfiltered0mm  35.233442
# 191   w_h2o__3m_uw              q7_flags36000_snowfallfilteredno  35.521246
# 192   w_h2o__3m_uw            q7_flags3600_snowfallfiltered0.5mm  34.467341
# 193   w_h2o__3m_uw              q7_flags3600_snowfallfiltered0mm  34.377129
# 194   w_h2o__3m_uw               q7_flags3600_snowfallfilteredno  34.467341
# 195   w_h2o__3m_uw            q7_flags9000_snowfallfiltered0.5mm  34.836575
# 196   w_h2o__3m_uw              q7_flags9000_snowfallfiltered0mm  34.616753
# 197   w_h2o__3m_uw               q7_flags9000_snowfallfilteredno  34.836575
# 198    w_h2o__5m_c  nodespiking_flags36000_snowfallfiltered0.5mm  38.211772
# 199    w_h2o__5m_c    nodespiking_flags36000_snowfallfiltered0mm  37.714698
# 200    w_h2o__5m_c     nodespiking_flags36000_snowfallfilteredno  37.651789
# 201    w_h2o__5m_c   nodespiking_flags3600_snowfallfiltered0.5mm  37.340821
# 202    w_h2o__5m_c     nodespiking_flags3600_snowfallfiltered0mm  36.862644
# 203    w_h2o__5m_c      nodespiking_flags3600_snowfallfilteredno  36.822637
# 204    w_h2o__5m_c   nodespiking_flags9000_snowfallfiltered0.5mm  37.741260
# 205    w_h2o__5m_c     nodespiking_flags9000_snowfallfiltered0mm  37.202124
# 206    w_h2o__5m_c      nodespiking_flags9000_snowfallfilteredno  37.152463
# 207    w_h2o__5m_c           q7_flags36000_snowfallfiltered0.5mm  36.496616
# 208    w_h2o__5m_c             q7_flags36000_snowfallfiltered0mm  36.043368
# 209    w_h2o__5m_c              q7_flags36000_snowfallfilteredno  36.496616
# 210    w_h2o__5m_c            q7_flags3600_snowfallfiltered0.5mm  35.686772
# 211    w_h2o__5m_c              q7_flags3600_snowfallfiltered0mm  35.257570
# 212    w_h2o__5m_c               q7_flags3600_snowfallfilteredno  35.686772
# 213    w_h2o__5m_c            q7_flags9000_snowfallfiltered0.5mm  36.052967
# 214    w_h2o__5m_c              q7_flags9000_snowfallfiltered0mm  35.559588
# 215    w_h2o__5m_c               q7_flags9000_snowfallfilteredno  36.052967
#
#        despiking instrument_flagging     snowfall_filtering  height tower
# 0    nodespiking          flags36000  snowfallfiltered0.5mm      10     c
# 1    nodespiking          flags36000    snowfallfiltered0mm      10     c
# 2    nodespiking          flags36000     snowfallfilteredno      10     c
# 3    nodespiking           flags3600  snowfallfiltered0.5mm      10     c
# 4    nodespiking           flags3600    snowfallfiltered0mm      10     c
# 5    nodespiking           flags3600     snowfallfilteredno      10     c
# 6    nodespiking           flags9000  snowfallfiltered0.5mm      10     c
# 7    nodespiking           flags9000    snowfallfiltered0mm      10     c
# 8    nodespiking           flags9000     snowfallfilteredno      10     c
# 9             q7          flags36000  snowfallfiltered0.5mm      10     c
# 10            q7          flags36000    snowfallfiltered0mm      10     c
# 11            q7          flags36000     snowfallfilteredno      10     c
# 12            q7           flags3600  snowfallfiltered0.5mm      10     c
# 13            q7           flags3600    snowfallfiltered0mm      10     c
# 14            q7           flags3600     snowfallfilteredno      10     c
# 15            q7           flags9000  snowfallfiltered0.5mm      10     c
# 16            q7           flags9000    snowfallfiltered0mm      10     c
# 17            q7           flags9000     snowfallfilteredno      10     c
# 18   nodespiking          flags36000  snowfallfiltered0.5mm      10     d
# 19   nodespiking          flags36000    snowfallfiltered0mm      10     d
# 20   nodespiking          flags36000     snowfallfilteredno      10     d
# 21   nodespiking           flags3600  snowfallfiltered0.5mm      10     d
# 22   nodespiking           flags3600    snowfallfiltered0mm      10     d
# 23   nodespiking           flags3600     snowfallfilteredno      10     d
# 24   nodespiking           flags9000  snowfallfiltered0.5mm      10     d
# 25   nodespiking           flags9000    snowfallfiltered0mm      10     d
# 26   nodespiking           flags9000     snowfallfilteredno      10     d
# 27            q7          flags36000  snowfallfiltered0.5mm      10     d
# 28            q7          flags36000    snowfallfiltered0mm      10     d
# 29            q7          flags36000     snowfallfilteredno      10     d
# 30            q7           flags3600  snowfallfiltered0.5mm      10     d
# 31            q7           flags3600    snowfallfiltered0mm      10     d
# 32            q7           flags3600     snowfallfilteredno      10     d
# 33            q7           flags9000  snowfallfiltered0.5mm      10     d
# 34            q7           flags9000    snowfallfiltered0mm      10     d
# 35            q7           flags9000     snowfallfilteredno      10     d
# 36   nodespiking          flags36000  snowfallfiltered0.5mm      10    ue
# 37   nodespiking          flags36000    snowfallfiltered0mm      10    ue
# 38   nodespiking          flags36000     snowfallfilteredno      10    ue
# 39   nodespiking           flags3600  snowfallfiltered0.5mm      10    ue
# 40   nodespiking           flags3600    snowfallfiltered0mm      10    ue
# 41   nodespiking           flags3600     snowfallfilteredno      10    ue
# 42   nodespiking           flags9000  snowfallfiltered0.5mm      10    ue
# 43   nodespiking           flags9000    snowfallfiltered0mm      10    ue
# 44   nodespiking           flags9000     snowfallfilteredno      10    ue
# 45            q7          flags36000  snowfallfiltered0.5mm      10    ue
# 46            q7          flags36000    snowfallfiltered0mm      10    ue
# 47            q7          flags36000     snowfallfilteredno      10    ue
# 48            q7           flags3600  snowfallfiltered0.5mm      10    ue
# 49            q7           flags3600    snowfallfiltered0mm      10    ue
# 50            q7           flags3600     snowfallfilteredno      10    ue
# 51            q7           flags9000  snowfallfiltered0.5mm      10    ue
# 52            q7           flags9000    snowfallfiltered0mm      10    ue
# 53            q7           flags9000     snowfallfilteredno      10    ue
# 54   nodespiking          flags36000  snowfallfiltered0.5mm      10    uw
# 55   nodespiking          flags36000    snowfallfiltered0mm      10    uw
# 56   nodespiking          flags36000     snowfallfilteredno      10    uw
# 57   nodespiking           flags3600  snowfallfiltered0.5mm      10    uw
# 58   nodespiking           flags3600    snowfallfiltered0mm      10    uw
# 59   nodespiking           flags3600     snowfallfilteredno      10    uw
# 60   nodespiking           flags9000  snowfallfiltered0.5mm      10    uw
# 61   nodespiking           flags9000    snowfallfiltered0mm      10    uw
# 62   nodespiking           flags9000     snowfallfilteredno      10    uw
# 63            q7          flags36000  snowfallfiltered0.5mm      10    uw
# 64            q7          flags36000    snowfallfiltered0mm      10    uw
# 65            q7          flags36000     snowfallfilteredno      10    uw
# 66            q7           flags3600  snowfallfiltered0.5mm      10    uw
# 67            q7           flags3600    snowfallfiltered0mm      10    uw
# 68            q7           flags3600     snowfallfilteredno      10    uw
# 69            q7           flags9000  snowfallfiltered0.5mm      10    uw
# 70            q7           flags9000    snowfallfiltered0mm      10    uw
# 71            q7           flags9000     snowfallfilteredno      10    uw
# 72   nodespiking          flags36000  snowfallfiltered0.5mm      15     c
# 73   nodespiking          flags36000    snowfallfiltered0mm      15     c
# 74   nodespiking          flags36000     snowfallfilteredno      15     c
# 75   nodespiking           flags3600  snowfallfiltered0.5mm      15     c
# 76   nodespiking           flags3600    snowfallfiltered0mm      15     c
# 77   nodespiking           flags3600     snowfallfilteredno      15     c
# 78   nodespiking           flags9000  snowfallfiltered0.5mm      15     c
# 79   nodespiking           flags9000    snowfallfiltered0mm      15     c
# 80   nodespiking           flags9000     snowfallfilteredno      15     c
# 81            q7          flags36000  snowfallfiltered0.5mm      15     c
# 82            q7          flags36000    snowfallfiltered0mm      15     c
# 83            q7          flags36000     snowfallfilteredno      15     c
# 84            q7           flags3600  snowfallfiltered0.5mm      15     c
# 85            q7           flags3600    snowfallfiltered0mm      15     c
# 86            q7           flags3600     snowfallfilteredno      15     c
# 87            q7           flags9000  snowfallfiltered0.5mm      15     c
# 88            q7           flags9000    snowfallfiltered0mm      15     c
# 89            q7           flags9000     snowfallfilteredno      15     c
# 90   nodespiking          flags36000  snowfallfiltered0.5mm      20     c
# 91   nodespiking          flags36000    snowfallfiltered0mm      20     c
# 92   nodespiking          flags36000     snowfallfilteredno      20     c
# 93   nodespiking           flags3600  snowfallfiltered0.5mm      20     c
# 94   nodespiking           flags3600    snowfallfiltered0mm      20     c
# 95   nodespiking           flags3600     snowfallfilteredno      20     c
# 96   nodespiking           flags9000  snowfallfiltered0.5mm      20     c
# 97   nodespiking           flags9000    snowfallfiltered0mm      20     c
# 98   nodespiking           flags9000     snowfallfilteredno      20     c
# 99            q7          flags36000  snowfallfiltered0.5mm      20     c
# 100           q7          flags36000    snowfallfiltered0mm      20     c
# 101           q7          flags36000     snowfallfilteredno      20     c
# 102           q7           flags3600  snowfallfiltered0.5mm      20     c
# 103           q7           flags3600    snowfallfiltered0mm      20     c
# 104           q7           flags3600     snowfallfilteredno      20     c
# 105           q7           flags9000  snowfallfiltered0.5mm      20     c
# 106           q7           flags9000    snowfallfiltered0mm      20     c
# 107           q7           flags9000     snowfallfilteredno      20     c
# 108  nodespiking          flags36000  snowfallfiltered0.5mm       2     c
# 109  nodespiking          flags36000    snowfallfiltered0mm       2     c
# 110  nodespiking          flags36000     snowfallfilteredno       2     c
# 111  nodespiking           flags3600  snowfallfiltered0.5mm       2     c
# 112  nodespiking           flags3600    snowfallfiltered0mm       2     c
# 113  nodespiking           flags3600     snowfallfilteredno       2     c
# 114  nodespiking           flags9000  snowfallfiltered0.5mm       2     c
# 115  nodespiking           flags9000    snowfallfiltered0mm       2     c
# 116  nodespiking           flags9000     snowfallfilteredno       2     c
# 117           q7          flags36000  snowfallfiltered0.5mm       2     c
# 118           q7          flags36000    snowfallfiltered0mm       2     c
# 119           q7          flags36000     snowfallfilteredno       2     c
# 120           q7           flags3600  snowfallfiltered0.5mm       2     c
# 121           q7           flags3600    snowfallfiltered0mm       2     c
# 122           q7           flags3600     snowfallfilteredno       2     c
# 123           q7           flags9000  snowfallfiltered0.5mm       2     c
# 124           q7           flags9000    snowfallfiltered0mm       2     c
# 125           q7           flags9000     snowfallfilteredno       2     c
# 126  nodespiking          flags36000  snowfallfiltered0.5mm       3     c
# 127  nodespiking          flags36000    snowfallfiltered0mm       3     c
# 128  nodespiking          flags36000     snowfallfilteredno       3     c
# 129  nodespiking           flags3600  snowfallfiltered0.5mm       3     c
# 130  nodespiking           flags3600    snowfallfiltered0mm       3     c
# 131  nodespiking           flags3600     snowfallfilteredno       3     c
# 132  nodespiking           flags9000  snowfallfiltered0.5mm       3     c
# 133  nodespiking           flags9000    snowfallfiltered0mm       3     c
# 134  nodespiking           flags9000     snowfallfilteredno       3     c
# 135           q7          flags36000  snowfallfiltered0.5mm       3     c
# 136           q7          flags36000    snowfallfiltered0mm       3     c
# 137           q7          flags36000     snowfallfilteredno       3     c
# 138           q7           flags3600  snowfallfiltered0.5mm       3     c
# 139           q7           flags3600    snowfallfiltered0mm       3     c
# 140           q7           flags3600     snowfallfilteredno       3     c
# 141           q7           flags9000  snowfallfiltered0.5mm       3     c
# 142           q7           flags9000    snowfallfiltered0mm       3     c
# 143           q7           flags9000     snowfallfilteredno       3     c
# 144  nodespiking          flags36000  snowfallfiltered0.5mm       3     d
# 145  nodespiking          flags36000    snowfallfiltered0mm       3     d
# 146  nodespiking          flags36000     snowfallfilteredno       3     d
# 147  nodespiking           flags3600  snowfallfiltered0.5mm       3     d
# 148  nodespiking           flags3600    snowfallfiltered0mm       3     d
# 149  nodespiking           flags3600     snowfallfilteredno       3     d
# 150  nodespiking           flags9000  snowfallfiltered0.5mm       3     d
# 151  nodespiking           flags9000    snowfallfiltered0mm       3     d
# 152  nodespiking           flags9000     snowfallfilteredno       3     d
# 153           q7          flags36000  snowfallfiltered0.5mm       3     d
# 154           q7          flags36000    snowfallfiltered0mm       3     d
# 155           q7          flags36000     snowfallfilteredno       3     d
# 156           q7           flags3600  snowfallfiltered0.5mm       3     d
# 157           q7           flags3600    snowfallfiltered0mm       3     d
# 158           q7           flags3600     snowfallfilteredno       3     d
# 159           q7           flags9000  snowfallfiltered0.5mm       3     d
# 160           q7           flags9000    snowfallfiltered0mm       3     d
# 161           q7           flags9000     snowfallfilteredno       3     d
# 162  nodespiking          flags36000  snowfallfiltered0.5mm       3    ue
# 163  nodespiking          flags36000    snowfallfiltered0mm       3    ue
# 164  nodespiking          flags36000     snowfallfilteredno       3    ue
# 165  nodespiking           flags3600  snowfallfiltered0.5mm       3    ue
# 166  nodespiking           flags3600    snowfallfiltered0mm       3    ue
# 167  nodespiking           flags3600     snowfallfilteredno       3    ue
# 168  nodespiking           flags9000  snowfallfiltered0.5mm       3    ue
# 169  nodespiking           flags9000    snowfallfiltered0mm       3    ue
# 170  nodespiking           flags9000     snowfallfilteredno       3    ue
# 171           q7          flags36000  snowfallfiltered0.5mm       3    ue
# 172           q7          flags36000    snowfallfiltered0mm       3    ue
# 173           q7          flags36000     snowfallfilteredno       3    ue
# 174           q7           flags3600  snowfallfiltered0.5mm       3    ue
# 175           q7           flags3600    snowfallfiltered0mm       3    ue
# 176           q7           flags3600     snowfallfilteredno       3    ue
# 177           q7           flags9000  snowfallfiltered0.5mm       3    ue
# 178           q7           flags9000    snowfallfiltered0mm       3    ue
# 179           q7           flags9000     snowfallfilteredno       3    ue
# 180  nodespiking          flags36000  snowfallfiltered0.5mm       3    uw
# 181  nodespiking          flags36000    snowfallfiltered0mm       3    uw
# 182  nodespiking          flags36000     snowfallfilteredno       3    uw
# 183  nodespiking           flags3600  snowfallfiltered0.5mm       3    uw
# 184  nodespiking           flags3600    snowfallfiltered0mm       3    uw
# 185  nodespiking           flags3600     snowfallfilteredno       3    uw
# 186  nodespiking           flags9000  snowfallfiltered0.5mm       3    uw
# 187  nodespiking           flags9000    snowfallfiltered0mm       3    uw
# 188  nodespiking           flags9000     snowfallfilteredno       3    uw
# 189           q7          flags36000  snowfallfiltered0.5mm       3    uw
# 190           q7          flags36000    snowfallfiltered0mm       3    uw
# 191           q7          flags36000     snowfallfilteredno       3    uw
# 192           q7           flags3600  snowfallfiltered0.5mm       3    uw
# 193           q7           flags3600    snowfallfiltered0mm       3    uw
# 194           q7           flags3600     snowfallfilteredno       3    uw
# 195           q7           flags9000  snowfallfiltered0.5mm       3    uw
# 196           q7           flags9000    snowfallfiltered0mm       3    uw
# 197           q7           flags9000     snowfallfilteredno       3    uw
# 198  nodespiking          flags36000  snowfallfiltered0.5mm       5     c
# 199  nodespiking          flags36000    snowfallfiltered0mm       5     c
# 200  nodespiking          flags36000     snowfallfilteredno       5     c
# 201  nodespiking           flags3600  snowfallfiltered0.5mm       5     c
# 202  nodespiking           flags3600    snowfallfiltered0mm       5     c
# 203  nodespiking           flags3600     snowfallfilteredno       5     c
# 204  nodespiking           flags9000  snowfallfiltered0.5mm       5     c
# 205  nodespiking           flags9000    snowfallfiltered0mm       5     c
# 206  nodespiking           flags9000     snowfallfilteredno       5     c
# 207           q7          flags36000  snowfallfiltered0.5mm       5     c
# 208           q7          flags36000    snowfallfiltered0mm       5     c
# 209           q7          flags36000     snowfallfilteredno       5     c
# 210           q7           flags3600  snowfallfiltered0.5mm       5     c
# 211           q7           flags3600    snowfallfiltered0mm       5     c
# 212           q7           flags3600     snowfallfilteredno       5     c
# 213           q7           flags9000  snowfallfiltered0.5mm       5     c
# 214           q7           flags9000    snowfallfiltered0mm       5     c
# 215           q7           flags9000     snowfallfilteredno       5     c

# %%
alt.Chart(totals_gapfilled_df).mark_point(size=100).encode(
    alt.X('value:Q').scale(zero=False, domain=[20,40]),
    alt.Y('height:Q'),
    alt.Shape('tower:N'),
    alt.Column('instrument_flagging').sort(['flags36000', 'flags9000', 'flags3600']),
    alt.Row('despiking'),
    alt.Color('snowfall_filtering')
).properties(width=150, height = 150).display(renderer='svg')
# Out:
# alt.Chart(...)

# %%
def restrict_time(src):
    return src[
        (
            src.time > '20221221'
        )&(
            src.time < '20221223'
        )
    ]
alt.Chart(restrict_time(
    df.query("variable == 'w_h2o__20m_c'")
)).mark_line().encode(
    alt.X('time:T'),
    alt.Y('value:Q'),
    alt.Color('processing'),
    facet='processing'
)
