# %%
import pandas as pd

# %%
fn = "/Users/elischwat/Development/data/sublimationofsnow/planar_fit_processed/"
fn_30 = "/Users/elischwat/Development/data/sublimationofsnow/planar_fit_processed_30min/"

# %%
df = pd.read_parquet(fn)
df_30 = pd.read_parquet(fn_30)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
(df['w_h2o__3m_c'].loc['20221129':'20230509'].cumsum()*5*60/1000).plot()
(df['w_h2o__3m_c_fit'].loc['20221129':'20230509'].cumsum()*5*60/1000).plot()
# Out:
# <Axes: xlabel='time'>

# %%
df.loc['20230101': '20230101', 'w_20m_c'].plot()
df.loc['20230101': '20230101', 'w_20m_c_fit'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df_30.loc['20230101': '20230101', 'w_20m_c'].plot()
df_30.loc['20230101': '20230101', 'w_20m_c_fit'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df.loc['20230101': '20230101', 'w_h2o__20m_c'].plot()
df.loc['20230101': '20230101', 'w_h2o__20m_c_fit'].plot()
# Out:
# <Axes: xlabel='time'>
